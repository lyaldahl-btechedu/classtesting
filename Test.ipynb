# %%
import pandas as pd
df =pd.read_csv("\Downloads\World-happiness-report-updated_2024.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-b281d068e521> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df =pd.read_csv("\Downloads\World-happiness-report-updated_2024.csv")
#
# ...

# %%
df =pd.read_csv("/content/World-happiness-report-updated_2024.csv", encoding='latin-1' )
print(df)
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.350           0.451
# 1     Afghanistan  2009        4.402               7.509           0.552
# 2     Afghanistan  2010        4.758               7.614           0.539
# 3     Afghanistan  2011        3.832               7.581           0.521
# 4     Afghanistan  2012        3.783               7.661           0.521
# ...           ...   ...          ...                 ...             ...
# 2358     Zimbabwe  2019        2.694               7.698           0.759
# 2359     Zimbabwe  2020        3.160               7.596           0.717
# 2360     Zimbabwe  2021        3.155               7.657           0.685
# 2361     Zimbabwe  2022        3.296               7.670           0.666
# 2362     Zimbabwe  2023        3.572               7.679           0.694
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
df.head()
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724               7.350           0.451
# 1  Afghanistan  2009        4.402               7.509           0.552
# 2  Afghanistan  2010        4.758               7.614           0.539
# 3  Afghanistan  2011        3.832               7.581           0.521
# 4  Afghanistan  2012        3.783               7.661           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                              50.5                         0.718       0.164
# 1                              50.8                         0.679       0.187
# 2                              51.1                         0.600       0.118
# 3                              51.4                         0.496       0.160
# 4                              51.7                         0.531       0.234
#
#    Perceptions of corruption  Positive affect  Negative affect
# ...

# %%
df.describe()
# Out:
#               year  Life Ladder  Log GDP per capita  Social support  \
# count  2363.000000  2363.000000         2335.000000     2350.000000
# mean   2014.763860     5.483566            9.399671        0.809369
# std       5.059436     1.125522            1.152069        0.121212
# min    2005.000000     1.281000            5.527000        0.228000
# 25%    2011.000000     4.647000            8.506500        0.744000
# 50%    2015.000000     5.449000            9.503000        0.834500
# 75%    2019.000000     6.323500           10.392500        0.904000
# max    2023.000000     8.019000           11.676000        0.987000
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       2300.000000                   2327.000000
# mean                          63.401828                      0.750282
# std                            6.842644                      0.139357
# min                            6.720000                      0.228000
# ...

# %% [markdown]
# # New Section

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2363 entries, 0 to 2362
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      2363 non-null   object
#  1   year                              2363 non-null   int64
#  2   Life Ladder                       2363 non-null   float64
#  3   Log GDP per capita                2335 non-null   float64
#  4   Social support                    2350 non-null   float64
#  5   Healthy life expectancy at birth  2300 non-null   float64
#  6   Freedom to make life choices      2327 non-null   float64
#  7   Generosity                        2282 non-null   float64
#  8   Perceptions of corruption         2238 non-null   float64
#  9   Positive affect                   2339 non-null   float64
#  10  Negative affect                   2347 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# ...

# %%
df.columns
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect'],
#       dtype='object')

# %%
df.sort_values(by='year', ascending= False)
# Out:
#       Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 2362      Zimbabwe  2023        3.572               7.679           0.694
# 1647      Paraguay  2023        6.214               9.549           0.889
# 307   Burkina Faso  2023        4.462               7.693           0.580
# 330       Cambodia  2023        4.221               8.462           0.738
# 1099         Kenya  2023        4.496               8.523           0.703
# ...            ...   ...          ...                 ...             ...
# 1722       Romania  2005        5.049               9.733           0.838
# 735        Germany  2005        6.620              10.691           0.963
# 2137       Türkiye  2005        4.719               9.800           0.820
# 81       Australia  2005        7.341              10.662           0.968
# 923           Iran  2005        5.308               9.498           0.766
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
df[['Country name', 'Life Ladder']].groupby('Country name').count().sort_values(by='Life Ladder', ascending= False)
# Out:
#               Life Ladder
# Country name
# Lebanon                18
# Jordan                 18
# Nicaragua              18
# Nepal                  18
# Moldova                18
# ...                   ...
# Cuba                    1
# Suriname                1
# Guyana                  1
# Oman                    1
# Maldives                1
#
# [165 rows x 1 columns]

# %%
df[['Country name', 'year','Perceptions of corruption']].groupby(['Country name', 'year']).max()
# Out:
#                    Perceptions of corruption
# Country name year
# Afghanistan  2008                      0.882
#              2009                      0.850
#              2010                      0.707
#              2011                      0.731
#              2012                      0.776
# ...                                      ...
# Zimbabwe     2019                      0.831
#              2020                      0.789
#              2021                      0.757
#              2022                      0.753
#              2023                      0.757
#
# [2363 rows x 1 columns]

# %%
df[['Country name', 'year','Perceptions of corruption']].groupby(['Country name', 'year']).min()
# Out:
#                    Perceptions of corruption
# Country name year
# Afghanistan  2008                      0.882
#              2009                      0.850
#              2010                      0.707
#              2011                      0.731
#              2012                      0.776
# ...                                      ...
# Zimbabwe     2019                      0.831
#              2020                      0.789
#              2021                      0.757
#              2022                      0.753
#              2023                      0.757
#
# [2363 rows x 1 columns]

# %%
df[['Country name', 'year','Perceptions of corruption']].groupby(['Country name', 'year']).min()
# Out:
#                    Perceptions of corruption
# Country name year
# Afghanistan  2008                      0.882
#              2009                      0.850
#              2010                      0.707
#              2011                      0.731
#              2012                      0.776
# ...                                      ...
# Zimbabwe     2019                      0.831
#              2020                      0.789
#              2021                      0.757
#              2022                      0.753
#              2023                      0.757
#
# [2363 rows x 1 columns]

# %%
df.iloc[:,0]
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 2358       Zimbabwe
# 2359       Zimbabwe
# 2360       Zimbabwe
# 2361       Zimbabwe
# 2362       Zimbabwe
# Name: Country name, Length: 2363, dtype: object

# %%
df.groupby('Country name').agg({'Life Ladder' : 'mean'})
# Out:
#               Life Ladder
# Country name
# Afghanistan      3.219933
# Albania          5.072750
# Algeria          5.392000
# Angola           4.420250
# Argentina        6.289667
# ...                   ...
# Venezuela        5.951111
# Vietnam          5.437556
# Yemen            3.862071
# Zambia           4.365882
# Zimbabwe         3.792333
#
# [165 rows x 1 columns]

# %%
df.groupby('year').agg({'Perceptions of corruption': 'max'})
# Out:
#       Perceptions of corruption
# year
# 2005                      0.983
# 2006                      0.967
# 2007                      0.976
# 2008                      0.968
# 2009                      0.979
# 2010                      0.983
# 2011                      0.977
# 2012                      0.962
# 2013                      0.973
# 2014                      0.976
# 2015                      0.962
# 2016                      0.969
# 2017                      0.954
# 2018                      0.952
# 2019                      0.963
# 2020                      0.961
# 2021                      0.946
# 2022                      0.942
# 2023                      0.948

# %%
df[['Perceptions of corruption', 'Life Ladder','Log GDP per capita']].corr()
# Out:
#                            Perceptions of corruption  Life Ladder  \
# Perceptions of corruption                   1.000000    -0.430485
# Life Ladder                                -0.430485     1.000000
# Log GDP per capita                         -0.353893     0.783556
#
#                            Log GDP per capita
# Perceptions of corruption           -0.353893
# Life Ladder                          0.783556
# Log GDP per capita                   1.000000

# %%
2>4
# Out:
# False

# %%
2==4
# Out:
# False

# %%
2!=4
# Out:
# True

# %%
place = "Mississippi"
len(place)<=10
# Out:
# False

# %%
df.head()
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724               7.350           0.451
# 1  Afghanistan  2009        4.402               7.509           0.552
# 2  Afghanistan  2010        4.758               7.614           0.539
# 3  Afghanistan  2011        3.832               7.581           0.521
# 4  Afghanistan  2012        3.783               7.661           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                              50.5                         0.718       0.164
# 1                              50.8                         0.679       0.187
# 2                              51.1                         0.600       0.118
# 3                              51.4                         0.496       0.160
# 4                              51.7                         0.531       0.234
#
#    Perceptions of corruption  Positive affect  Negative affect
# ...

# %%
df['year']== 2023
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2358    False
# 2359    False
# 2360    False
# 2361    False
# 2362     True
# Name: year, Length: 2363, dtype: bool

# %%
df[((df['Country name'] == 'United States') | (df['Country name'] == 'China') & (df['year'] == 2023))]
# Out:
#        Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 422           China  2023        6.145               9.861           0.797
# 2225  United States  2006        7.182              10.921           0.965
# 2226  United States  2007        7.513              10.931             NaN
# 2227  United States  2008        7.280              10.923           0.953
# 2228  United States  2009        7.158              10.888           0.912
# 2229  United States  2010        7.164              10.906           0.926
# 2230  United States  2011        7.115              10.914           0.922
# 2231  United States  2012        7.026              10.929           0.903
# 2232  United States  2013        7.249              10.941           0.925
# 2233  United States  2014        7.151              10.956           0.902
# 2234  United States  2015        6.864              10.975           0.904
# ...

# %%
df.isna().sum()
# Out:
# Country name                          0
# year                                  0
# Life Ladder                           0
# Log GDP per capita                   28
# Social support                       13
# Healthy life expectancy at birth     63
# Freedom to make life choices         36
# Generosity                           81
# Perceptions of corruption           125
# Positive affect                      24
# Negative affect                      16
# dtype: int64

# %%
df[df.isna().any(axis = 1)]
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 13    Afghanistan  2022        1.281                 NaN           0.228
# 14    Afghanistan  2023        1.446                 NaN           0.368
# 31        Algeria  2010        5.464               9.306             NaN
# 34        Algeria  2014        6.355               9.355           0.818
# 35        Algeria  2016        5.341               9.383           0.749
# ...           ...   ...          ...                 ...             ...
# 2314        Yemen  2007        4.477               8.212           0.825
# 2322        Yemen  2016        3.826               7.552           0.775
# 2323        Yemen  2017        3.254               7.243           0.790
# 2326        Yemen  2022        3.590                 NaN           0.872
# 2327        Yemen  2023        3.532                 NaN           0.825
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
df['Country name'].nunique()
# Out:
# 165

# %%
df_f = df.loc[:, ['Country name','Perceptions of corruption']]
df_f
# Out:
#      Country name  Perceptions of corruption
# 0     Afghanistan                      0.882
# 1     Afghanistan                      0.850
# 2     Afghanistan                      0.707
# 3     Afghanistan                      0.731
# 4     Afghanistan                      0.776
# ...           ...                        ...
# 2358     Zimbabwe                      0.831
# 2359     Zimbabwe                      0.789
# 2360     Zimbabwe                      0.757
# 2361     Zimbabwe                      0.753
# 2362     Zimbabwe                      0.757
#
# [2363 rows x 2 columns]

# %%
df_f = df_f.groupby('Country name').mean()
df_f
# Out:
#               Perceptions of corruption
# Country name
# Afghanistan                    0.835800
# Albania                        0.868688
# Algeria                        0.688111
# Angola                         0.866750
# Argentina                      0.839056
# ...                                 ...
# Venezuela                      0.798611
# Vietnam                        0.771000
# Yemen                          0.816455
# Zambia                         0.821059
# Zimbabwe                       0.829444
#
# [165 rows x 1 columns]

# %%
df_f[df_f["Perceptions of corruption"].isna()]
# Out:
#               Perceptions of corruption
# Country name
# China                               NaN
# Cuba                                NaN
# Maldives                            NaN
# Oman                                NaN
# Turkmenistan                        NaN
